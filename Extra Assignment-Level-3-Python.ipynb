# %%
Value=int(input("Enter a value from 0 to 10:"))
if (Value==10):
    print("Correct")
else:
    print("Incorrect")
# Out:
# Enter a value from 0 to 10: 10
# Correct

# %%
password=(input("Enter the password:"))
import re
if (re.search(r"[A-Z]",password) and 
   re.search(r"\d",password) and
   re.search(r"[!@#$%^&*(),.?\":{}|<>]",password)):
    print("Your password is correct")
else:
    print("Your password is incorrect, please enter a password with atleast one Uppercase,special character.")
# Out:
# Enter the password: HOPE@123
# Your password is correct

# %%
Age=int(input("Age:"))
if (Age<15):
    print("Children")
elif (Age>15 and Age<25):
    print("Adult")
elif (Age>25 and Age<40):
    print("citizen")
else:
    print("Senior citizen")
# Out:
# Age: 20
# Adult

# %%
number=float(input("Enter any number:"))
if (number>0):
    print("Number is positive.")
else:
    print("Number is negative")
# Out:
# Enter any number: 1
# Number is positive.

# %%
num=int(input("Enter a number to check:"))
if ()
